# %% [markdown]
# <a href="https://colab.research.google.com/github/james-caldwell1981/DS-Unit-1-Build-Sprint/blob/master/Build_Sprint_1_Caldwell_James_TL_Hadi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import all libraries

import pandas as pd
import numpy as np
import plotly.express as px
from plotly import figure_factory as ff
import plotly.graph_objects as go
from pdb import set_trace as st

# %%
#get data and data key
# !wget http://www.stat.columbia.edu/~gelman/arm/examples/speed.dating/Speed%20Dating%20Data%20Key.doc
# Out:
# --2020-08-26 02:40:52--  http://www.stat.columbia.edu/~gelman/arm/examples/speed.dating/Speed%20Dating%20Data%20Key.doc
# Resolving www.stat.columbia.edu (www.stat.columbia.edu)... 128.59.111.11
# Connecting to www.stat.columbia.edu (www.stat.columbia.edu)|128.59.111.11|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 161792 (158K) [application/msword]
# Saving to: ‘Speed Dating Data Key.doc.2’
#
# Speed Dating Data K 100%[===================>] 158.00K   298KB/s    in 0.5s
#
# 2020-08-26 02:40:54 (298 KB/s) - ‘Speed Dating Data Key.doc.2’ saved [161792/161792]

# %%
#read data into dataframe
df = pd.read_csv('/content/Speed_Dating_Data.csv')

# %%
df.head()
# Out:
#    iid   id  gender  idg  condtn  ...  attr5_3  sinc5_3  intel5_3  fun5_3  amb5_3
# 0    1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 1    1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 2    1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 3    1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 4    1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
#
# [5 rows x 195 columns]

# %%
#create df with only matched couples
matched_df = df[df['match']==1]

# %%
#create new column with age difference
matched_df['age_diff'] = abs(df['age']-df['age_o'])
matched_df['age_diff'].head()
# Out:
# 2     1.0
# 3     2.0
# 4     3.0
# 8     7.0
# 13    1.0
# Name: age_diff, dtype: float64

# %%
matched_df.shape
# Out:
# (1380, 196)

# %%
#create df with only unmatched couples
unmatched_df = df[df['match']==1]

# %%
#create new column with age difference
unmatched_df['age_diff'] = abs(df['age']-df['age_o'])
unmatched_df['age_diff'].head()
# Out:
# 2     1.0
# 3     2.0
# 4     3.0
# 8     7.0
# 13    1.0
# Name: age_diff, dtype: float64

# %%
unmatched_df.shape
# Out:
# (1380, 196)

# %%
matched_df.describe()
# Out:
#                iid           id  ...      amb5_3     age_diff
# count  1380.000000  1380.000000  ...  363.000000  1344.000000
# mean    278.031884     8.950725  ...    7.079890     3.181548
# std     158.472171     5.370848  ...    1.640882     2.669106
# min       1.000000     1.000000  ...    1.000000     0.000000
# 25%     142.000000     4.000000  ...    6.000000     1.000000
# 50%     274.000000     8.000000  ...    7.000000     3.000000
# 75%     404.000000    13.000000  ...    8.000000     5.000000
# max     552.000000    22.000000  ...   10.000000    17.000000
#
# [8 rows x 188 columns]

# %%
unmatched_df.describe()
# Out:
#                iid           id  ...      amb5_3     age_diff
# count  1380.000000  1380.000000  ...  363.000000  1344.000000
# mean    278.031884     8.950725  ...    7.079890     3.181548
# std     158.472171     5.370848  ...    1.640882     2.669106
# min       1.000000     1.000000  ...    1.000000     0.000000
# 25%     142.000000     4.000000  ...    6.000000     1.000000
# 50%     274.000000     8.000000  ...    7.000000     3.000000
# 75%     404.000000    13.000000  ...    8.000000     5.000000
# max     552.000000    22.000000  ...   10.000000    17.000000
#
# [8 rows x 188 columns]

# %%
matched_male = matched_df[matched_df['gender']==1]

# %%
unmatched_male = unmatched_df[unmatched_df['gender']==1]

# %%
matched_male = matched_df[matched_df['gender']==0]

# %%
unmatched_male = unmatched_df[unmatched_df['gender']==0]

# %%
careers = ['Law', 'Math', 'SocSciPsych', 'MedSciPharm', 'Engineering',
        'EngJourn', 'HistRelPhil', 'BusEconFin', 'Education', 'BioSciChemPhys',
        'SocialWork', 'UndGrad', 'PoliSciIntAffairs', 'Film', 'FineArtsAdmin',
        'Languages', 'Architecture', 'Other']

# %%
[i for i in df.columns]
# Out:
# ['iid',
#  'id',
#  'gender',
#  'idg',
#  'condtn',
#  'wave',
#  'round',
#  'position',
#  'positin1',
#  'order',
#  'partner',
#  'pid',
#  'match',
#  'int_corr',
#  'samerace',
#  'age_o',
#  'race_o',
#  'pf_o_att',
#  'pf_o_sin',
#  'pf_o_int',
#  'pf_o_fun',
#  'pf_o_amb',
#  'pf_o_sha',
#  'dec_o',
#  'attr_o',
#  'sinc_o',
#  'intel_o',
#  'fun_o',
#  'amb_o',
#  'shar_o',
#  'like_o',
#  'prob_o',
#  'met_o',
#  'age',
#  'field',
#  'field_cd',
#  'undergra',
#  'mn_sat',
#  'tuition',
#  'race',
#  'imprace',
#  'imprelig',
#  'from',
#  'zipcode',
#  'income',
#  'goal',
#  'date',
#  'go_out',
#  'career',
#  'career_c',
#  'sports',
#  'tvsports',
#  'exercise',
#  'dining',
#  'museums',
#  'art',
#  'hiking',
#  'gaming',
#  'clubbing',
#  'reading',
#  'tv',
#  'theater',
#  'movies',
#  'concerts',
#  'music',
#  'shopping',
#  'yoga',
#  'exphappy',
#  'expnum',
#  'attr1_1',
#  'sinc1_1',
#  'intel1_1',
#  'fun1_1',
#  'amb1_1',
#  'shar1_1',
#  'attr4_1',
# ...

# %%
# matched_df[matched_df['career_c']!=np.NaN]['career_c'].head(30)
# matched_df['career_c'].value_counts()
(matched_df[matched_df['career_c'] == 1])[["career"]].head(30)
# Out:
#                  career
# 33   lawyer/policy work
# 38   lawyer/policy work
# 43               lawyer
# 48               lawyer
# 53               lawyer
# 58               lawyer
# 63                  Law
# 68                  Law
# 117    Corporate Lawyer
# 118    Corporate Lawyer
# 120              Lawyer
# 127              Lawyer
# 128              Lawyer
# 129              Lawyer
# 130  Corporate attorney
# 131  Corporate attorney
# 133  Corporate attorney
# 134  Corporate attorney
# 135  Corporate attorney
# 136  Corporate attorney
# 137  Corporate attorney
# 138  Corporate attorney
# 140              Lawyer
# 147              Lawyer
# 148              Lawyer
# 353              Lawyer
# 359              Lawyer
# 368                 law
# 369                 law
# 370                 law

# %%
fig = go.Figure()

fig.add_trace(go.Bar(
    x=male_match_df.columns,
    y=[male_match_df[i].mean() for i in male_match_df.columns],
    name='Matched Male Interests',
    marker_color='rgb(50, 50, 200)'))

fig.add_trace(go.Bar(
    x=female_match_df.columns,
    y=[female_match_df[i].mean() for i in female_match_df.columns],
    name='Matched Female Interests',
    marker_color='rgb(230, 50, 50)'))

# Here we modify the tickangle of the xaxis, resulting in rotated labels.
fig.update_layout(barmode='group', plot_bgcolor='rgb(240,240,240)')
fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=male_match_df.columns,
    y=[male_match_df[i].mean() for i in male_match_df.columns],
    name='Matched Male Interests',
    mode='markers',
    marker=dict(color='rgb(50, 50, 200)', size=10),
))

fig.add_trace(go.Scatter(
    x=female_match_df.columns,
    y=[female_match_df[i].mean() for i in female_match_df.columns],
    name='Matched Female Interests',
    mode='markers',
    marker=dict(color='rgb(230, 50, 50)', size=10),
    marker_color='rgb(230, 50, 50)'))

# Here we modify the tickangle of the xaxis, resulting in rotated labels.
fig.update_layout(barmode='group', plot_bgcolor='rgb(240,240,240)')
fig.show()

# %%
df.head()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=df['wave'],
    y=df[],
    name='Matched Male Interests',
    mode='markers',
    marker=dict(color='rgb(50, 50, 200)', size=10),
))

fig.add_trace(go.Scatter(
    x=female_match_df.columns,
    y=[female_match_df[i].mean() for i in female_match_df.columns],
    name='Matched Female Interests',
    mode='markers',
    marker=dict(color='rgb(230, 50, 50)', size=10),
    marker_color='rgb(230, 50, 50)'))

# Here we modify the tickangle of the xaxis, resulting in rotated labels.
fig.update_layout(barmode='group', plot_bgcolor='rgb(240,240,240)')
fig.show()
