# %% [markdown]
# <a href="https://colab.research.google.com/github/james-caldwell1981/DS-Unit-1-Build-Sprint/blob/master/day1/Build_Sprint_1_Caldwell_James_TL_Hadi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
# !wget http://www.stat.columbia.edu/~gelman/arm/examples/speed.dating/Speed%20Dating%20Data%20Key.doc
# Out:
# --2020-08-20 02:29:15--  http://www.stat.columbia.edu/~gelman/arm/examples/speed.dating/Speed%20Dating%20Data%20Key.doc
# Resolving www.stat.columbia.edu (www.stat.columbia.edu)... 128.59.111.11
# Connecting to www.stat.columbia.edu (www.stat.columbia.edu)|128.59.111.11|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 161792 (158K) [application/msword]
# Saving to: ‘Speed Dating Data Key.doc.1’
#
# Speed Dating Data K 100%[===================>] 158.00K   348KB/s    in 0.5s
#
# 2020-08-20 02:29:16 (348 KB/s) - ‘Speed Dating Data Key.doc.1’ saved [161792/161792]

# %%
pd.options.display.max_rows = 200
pd.options.display.max_columns = 200

# %%
df = pd.read_csv('/content/Speed_Dating_Data.csv')

# %%
df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %%
df['career_c'].value_counts()
# Out:
# 2.0     2320
# 7.0     2170
# 6.0      724
# 1.0      675
# 9.0      547
# 4.0      421
# 10.0     379
# 3.0      261
# 5.0      234
# 11.0     220
# 13.0      81
# 15.0      77
# 16.0      44
# 8.0       39
# 12.0      28
# 17.0      10
# 14.0      10
# Name: career_c, dtype: int64

# %%
df['career_c'].describe()
# Out:
# count    8240.000000
# mean        5.277791
# std         3.309520
# min         1.000000
# 25%         2.000000
# 50%         6.000000
# 75%         7.000000
# max        17.000000
# Name: career_c, dtype: float64

# %%
[i for i in df.columns]
# Out:
# ['iid',
#  'id',
#  'gender',
#  'idg',
#  'condtn',
#  'wave',
#  'round',
#  'position',
#  'positin1',
#  'order',
#  'partner',
#  'pid',
#  'match',
#  'int_corr',
#  'samerace',
#  'age_o',
#  'race_o',
#  'pf_o_att',
#  'pf_o_sin',
#  'pf_o_int',
#  'pf_o_fun',
#  'pf_o_amb',
#  'pf_o_sha',
#  'dec_o',
#  'attr_o',
#  'sinc_o',
#  'intel_o',
#  'fun_o',
#  'amb_o',
#  'shar_o',
#  'like_o',
#  'prob_o',
#  'met_o',
#  'age',
#  'field',
#  'field_cd',
#  'undergra',
#  'mn_sat',
#  'tuition',
#  'race',
#  'imprace',
#  'imprelig',
#  'from',
#  'zipcode',
#  'income',
#  'goal',
#  'date',
#  'go_out',
#  'career',
#  'career_c',
#  'sports',
#  'tvsports',
#  'exercise',
#  'dining',
#  'museums',
#  'art',
#  'hiking',
#  'gaming',
#  'clubbing',
#  'reading',
#  'tv',
#  'theater',
#  'movies',
#  'concerts',
#  'music',
#  'shopping',
#  'yoga',
#  'exphappy',
#  'expnum',
#  'attr1_1',
#  'sinc1_1',
#  'intel1_1',
#  'fun1_1',
#  'amb1_1',
#  'shar1_1',
#  'attr4_1',
# ...

# %%
df.dtypes
# Out:
# iid           int64
# id          float64
# gender        int64
# idg           int64
# condtn        int64
# wave          int64
# round         int64
# position      int64
# positin1    float64
# order         int64
# partner       int64
# pid         float64
# match         int64
# int_corr    float64
# samerace      int64
# age_o       float64
# race_o      float64
# pf_o_att    float64
# pf_o_sin    float64
# pf_o_int    float64
# pf_o_fun    float64
# pf_o_amb    float64
# pf_o_sha    float64
# dec_o         int64
# attr_o      float64
# sinc_o      float64
# intel_o     float64
# fun_o       float64
# amb_o       float64
# shar_o      float64
# like_o      float64
# prob_o      float64
# met_o       float64
# age         float64
# field        object
# field_cd    float64
# undergra     object
# mn_sat       object
# tuition      object
# race        float64
# imprace     float64
# imprelig    float64
# from         object
# zipcode      object
# income       object
# ...

# %%
df.shape
# Out:
# (8378, 195)

# %%
df['id'].head(32)
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     1.0
# 7     1.0
# 8     1.0
# 9     1.0
# 10    2.0
# 11    2.0
# 12    2.0
# 13    2.0
# 14    2.0
# 15    2.0
# 16    2.0
# 17    2.0
# 18    2.0
# 19    2.0
# 20    3.0
# 21    3.0
# 22    3.0
# 23    3.0
# 24    3.0
# 25    3.0
# 26    3.0
# 27    3.0
# 28    3.0
# 29    3.0
# 30    4.0
# 31    4.0
# Name: id, dtype: float64

# %%
#Accidental transpose
#cols_ = ['match', 'field_cd']
#pd.DataFrame([df[i] for i in cols_]).T.head()

# %%
def xtab_creator(cols, gend=[0,1], match=[0,1]):

    print(df[[cols[0],cols[1], 'gender', 'match']].head())



#split df by gender
'''    female_filter = df['gender']==0
    female_df = df[female_filter]
    male_filter = df['gender']==1
    male_df = df[male_filter]'''
# Out:
# "    female_filter = df['gender']==0\n    female_df = df[female_filter]\n    male_filter = df['gender']==1\n    male_df = df[male_filter]"

# %%
testing = xtab_creator(['career_c', 'race'])
# Out:
#    career_c  race  gender  match
# 0       NaN   4.0       0      0
# 1       NaN   4.0       0      0
# 2       NaN   4.0       0      1
# 3       NaN   4.0       0      1
# 4       NaN   4.0       0      1

# %%
testing['career_c']

# %%
xtab_list = []

# %%
xtab_cols = ['Law', 'Math', 'SocSciPsych', 'MedSciPharm', 'Engineering',
             'EngJourn', 'HistRelPhil', 'BusEconFin', 'Education', 'BioSciChemPhys',
             'SocialWork', 'UndGrad', 'PoliSciIntAffairs', 'Film', 'FineArtsAdmin',
             'Languages', 'Architecture', 'Other', 'All']

# %%
career_xtab = pd.crosstab(df['match'], df['field_cd'], margins=True)
career_xtab.columns = xtab_cols
career_xtab.columns
# Out:
# Index(['Law', 'Math', 'SocSciPsych', 'MedSciPharm', 'Engineering', 'EngJourn',
#        'HistRelPhil', 'BusEconFin', 'Education', 'BioSciChemPhys',
#        'SocialWork', 'UndGrad', 'PoliSciIntAffairs', 'Film', 'FineArtsAdmin',
#        'Languages', 'Architecture', 'Other', 'All'],
#       dtype='object')

# %%
xtab_list.append('career')

# %%
xtab_list
# Out:
# ['career']
